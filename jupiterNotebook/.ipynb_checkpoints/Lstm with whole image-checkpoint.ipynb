# %%
# Cell 1: Imports and Global Variables
import pandas as pd
import os
import numpy as np
import cv2
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, TimeDistributed, LSTM, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from functools import lru_cache
import matplotlib.pyplot as plt
# %matplotlib inline

# Global variables
IMAGE_HEIGHT = 32
IMAGE_WIDTH = 32
IMAGE_CHANNELS = 3
BATCH_SIZE = 10
TIMESTEPS = 24
ECHPOS_SIZE=150

# %%
@lru_cache(maxsize=100000)
def load_and_preprocess_image(image_path):
    img = cv2.imread(image_path)
    if img is None:
        raise ValueError(f"Could not load image at {image_path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_resized = cv2.resize(img, (IMAGE_WIDTH, IMAGE_HEIGHT))
    # Normalize pixel values to [0, 1] instead of VGG16 preprocessing
    img_normalized = img_resized / 255.0
    return img_normalized

def load_images_with_data(image_dir="F:/Pheonix/Thesis/Project/Code/AQI Index/.venv/Dev/Data/cleaned_folder",
                         csv_file="F:/Pheonix/Thesis/Project/Code/AQI Index/.venv/Dev/Data/cleaned_data.csv"):
    df = pd.read_csv(csv_file)
    image_data_list = []
    
    for _, row in df.iterrows():
        image_name = row['Filename']
        image_path = os.path.join(image_dir, image_name)
        if os.path.exists(image_path):
            try:
                img_resized = load_and_preprocess_image(image_path)
                values = row.to_dict()
                values['image'] = img_resized
                image_data_list.append(values)
            except Exception as e:
                print(f"Error loading image {image_name}: {e}")
    return image_data_list

image_data_list = load_images_with_data()
print(f"Loaded {len(image_data_list)} images")
# Out:
# Loaded 10610 images

# %%
def prepare_dataset(image_data_list):
    """Prepare dataset with whole images, no segmentation."""
    X = []
    y_dict = {'AQI': [], 'PM2.5': [], 'PM10': [], 'O3': [], 'CO': [], 'SO2': [], 'NO2': []}
    sequence_X = []
    scalers = {}
    
    for i, data in enumerate(image_data_list):
        img = data['image']
        if img.shape != (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS):
            img = cv2.resize(img, (IMAGE_WIDTH, IMAGE_HEIGHT))
        
        sequence_X.append(img)
        for param in y_dict.keys():
            y_dict[param].append(data[param])
        
        if (i + 1) % TIMESTEPS == 0:
            X.append(np.array(sequence_X))
            sequence_X = []
    
    if sequence_X:
        remaining_steps = TIMESTEPS - len(sequence_X)
        padding = np.zeros((remaining_steps, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), dtype=np.float32)
        sequence_X = np.concatenate([np.array(sequence_X), padding], axis=0)
        X.append(sequence_X)
    
    X = np.array(X)
    
    # Normalize y values
    y_dict_seq = {}
    for param, values in y_dict.items():
        sequences = [values[i:i+TIMESTEPS] for i in range(0, len(values), TIMESTEPS)]
        if len(sequences[-1]) < TIMESTEPS:
            sequences[-1] = np.pad(sequences[-1], (0, TIMESTEPS - len(sequences[-1])), mode='constant', constant_values=0)
        sequences = np.array(sequences)
        scaler = StandardScaler()
        flat_values = sequences.reshape(-1, 1)
        scaled_values = scaler.fit_transform(flat_values).reshape(sequences.shape)
        y_dict_seq[param] = scaled_values
        scalers[param] = scaler
    
    print(f"Final X shape: {X.shape}")
    return X, y_dict_seq, scalers

X, y_dict, scalers = prepare_dataset(image_data_list)
print(f"Dataset shape: X={X.shape}, y_dict sample shape: {y_dict['AQI'].shape}")
# Out:
# Final X shape: (443, 24, 32, 32, 3)
# Dataset shape: X=(443, 24, 32, 32, 3), y_dict sample shape: (443, 24)

# %%
def build_cnn_lstm_model(input_shape=(TIMESTEPS, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)):
    """CNN-LSTM for 32x32 whole images."""
    model = Sequential([
        TimeDistributed(Conv2D(32, (3, 3), activation='relu', padding='same'), input_shape=input_shape),
        TimeDistributed(MaxPooling2D((2, 2))),  # 32x32 -> 16x16
        TimeDistributed(Conv2D(64, (3, 3), activation='relu', padding='same')),
        TimeDistributed(MaxPooling2D((2, 2))),  # 16x16 -> 8x8
        TimeDistributed(Flatten()),  # 8x8x64 = 4096 features per timestep
        LSTM(64, return_sequences=False),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1)
    ])
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['mae'])
    return model

model = build_cnn_lstm_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 24, 32, 32, 32)   896
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 24, 16, 16, 32)   0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 24, 16, 16, 64)   18496
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 24, 8, 8, 64)     0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 24, 4096)         0
#  tributed)
#
#  lstm (LSTM)                 (None, 64)                1065216
#
#  dense (Dense)               (None, 32)                2080
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,086,721
# Trainable params: 1,086,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
def train_models(X, y_dict):
    models = {}
    histories = {}
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    for param, y_values in y_dict.items():
        print(f"\nTraining model for {param}")
        X_train, X_test, y_train, y_test = train_test_split(X, y_values, test_size=0.2, random_state=42)
        print(f"Training samples: {X_train.shape[0]}, Testing samples: {X_test.shape[0]}")
        
        model = build_cnn_lstm_model()
        history = model.fit(
            X_train, y_train[:, -1],
            validation_data=(X_test, y_test[:, -1]),
            epochs=ECHPOS_SIZE,
            batch_size=BATCH_SIZE,
            callbacks=[early_stopping],
            verbose=1
        )
        models[param] = model
        histories[param] = history
        
        model_path = os.path.join("saved_models", f"model_{param}.h5")
        model.save(model_path)
        print(f"Saved model for {param} to {model_path}")
    
    return models, histories

models, histories = train_models(X, y_dict)
# Out:
# Training model for AQI
# Training samples: 354, Testing samples: 89
# Epoch 1/100
# 36/36 [==============================] - 17s 59ms/step - loss: 1.0045 - mae: 0.8169 - val_loss: 0.7272 - val_mae: 0.6886
# Epoch 2/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.9033 - mae: 0.7477 - val_loss: 0.6646 - val_mae: 0.6575
# Epoch 3/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.8202 - mae: 0.7122 - val_loss: 0.5553 - val_mae: 0.5281
# Epoch 4/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.7909 - mae: 0.6849 - val_loss: 0.5772 - val_mae: 0.5980
# Epoch 5/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.7359 - mae: 0.6553 - val_loss: 0.5926 - val_mae: 0.5338
# Epoch 6/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6563 - mae: 0.6298 - val_loss: 0.4398 - val_mae: 0.4879
# Epoch 7/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.5614 - mae: 0.5762 - val_loss: 0.3949 - val_mae: 0.4759
# Epoch 8/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.4671 - mae: 0.5289 - val_loss: 0.3565 - val_mae: 0.4508
# Epoch 9/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.4321 - mae: 0.5094 - val_loss: 0.6336 - val_mae: 0.6194
# Epoch 10/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.4230 - mae: 0.5014 - val_loss: 0.2915 - val_mae: 0.4181
# Epoch 11/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.3988 - mae: 0.4817 - val_loss: 0.4909 - val_mae: 0.5378
# Epoch 12/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.3803 - mae: 0.4854 - val_loss: 0.4211 - val_mae: 0.4987
# Epoch 13/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.4258 - mae: 0.4912 - val_loss: 0.6485 - val_mae: 0.6389
# Epoch 14/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.3797 - mae: 0.4740 - val_loss: 0.2800 - val_mae: 0.4195
# Epoch 15/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.
100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1132 - mae: 0.2430 - val_loss: 0.1666 - val_mae: 0.3052
# Epoch 51/100
# 36/36 [==============================] - 1s 23ms/step - loss: 0.1486 - mae: 0.2884 - val_loss: 0.1660 - val_mae: 0.2894
# Epoch 52/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1223 - mae: 0.2460 - val_loss: 0.1760 - val_mae: 0.2850
# Epoch 53/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.1019 - mae: 0.2408 - val_loss: 0.1530 - val_mae: 0.2745
# Epoch 54/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.0951 - mae: 0.2219 - val_loss: 0.1095 - val_mae: 0.2363
# Epoch 55/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.0963 - mae: 0.2159 - val_loss: 0.1405 - val_mae: 0.2573
# Epoch 56/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.1251 - mae: 0.2514 - val_loss: 0.1709 - val_mae: 0.3001
# Epoch 57/100
# 36/36 [==============================] - 1s 23ms/step - loss: 0.1188 - mae: 0.2335 - val_loss: 0.1348 - val_mae: 0.2632
# Epoch 58/100
# 36/36 [==============================] - 1s 23ms/step - loss: 0.1153 - mae: 0.2452 - val_loss: 0.2304 - val_mae: 0.3403
# Epoch 59/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.1214 - mae: 0.2561 - val_loss: 0.1380 - val_mae: 0.2509
# Epoch 60/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1162 - mae: 0.2477 - val_loss: 0.2336 - val_mae: 0.3163
# Epoch 61/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1052 - mae: 0.2388 - val_loss: 0.2023 - val_mae: 0.3036
# Epoch 62/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.0906 - mae: 0.2075 - val_loss: 0.1802 - val_mae: 0.2842
# Epoch 63/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1030 - mae: 0.2335 - val_loss: 0.1371 - val_mae: 0.2649
# Epoch 64/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.0661 - mae: 0.1942 - val_loss: 0.1804 - val_mae: 0.2777
# Saved model for PM2.5 to saved_models\model_PM2.5.h5
#
# Training model for PM10
# Training samples: 354, Testing samples: 89
# Epoch 1/100
# 36/36 [==============================] - 3s 37ms/step - loss: 1.0514 - mae: 0.7861 - val_loss: 1.0041 - val_mae: 0.8460
# Epoch 2/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.9709 - mae: 0.7782 - val_loss: 0.8355 - val_mae: 0.7119
# Epoch 3/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.8903 - mae: 0.7086 - val_loss: 0.6437 - val_mae: 0.5768
# Epoch 4/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.7257 - mae: 0.6182 - val_loss: 0.5540 - val_mae: 0.5231
# Epoch 5/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6547 - mae: 0.5837 - val_loss: 0.6905 - val_mae: 0.6826
# Epoch 6/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.8992 - mae: 0.7009 - val_loss: 0.6269 - val_mae: 0.5873
# Epoch 7/100
# 36/36 [==============================] - 1s 23ms/step - loss: 0.6296 - mae: 0.5731 - val_loss: 0.4887 - val_mae: 0.4971
# Epoch 8/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.6652 - mae: 0.5833 - val_loss: 0.4993 - val_mae: 0.4964
# Epoch 9/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.7774 - mae: 0.6239 - val_loss: 0.6390 - val_mae: 0.6300
# Epoch 10/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.6473 - mae: 0.5968 - val_loss: 0.4759 - val_mae: 0.4799
# Epoch 11/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.6266 - mae: 0.5587 - val_loss: 0.4746 - val_mae: 0.5110
# Epoch 12/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.5656 - mae: 0.5466 - val_loss: 0.4253 - val_mae: 0.4840
# Epoch 13/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.5137 - mae: 0.5265 - val_loss: 0.4272 - val_mae: 0.4708
# Epoch 14/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.5659 - mae: 0.5474 - val_loss: 0.3495 - val_mae: 0.4462
# Epoch 15/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.5250 - mae: 0.5257 - val_loss: 0.4033 - val_mae: 0.4864
# Epoch 16/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.5189 - mae: 0.5049 - val_loss: 0.3241 - val_mae: 0.4438
# Epoch 17/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.4558 - mae: 0.4918 - val_loss: 0.2877 - val_mae: 0.4113
# Epoch 18/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0
100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1063 - mae: 0.2377 - val_loss: 0.2160 - val_mae: 0.2769
# Epoch 57/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.1136 - mae: 0.2341 - val_loss: 0.2311 - val_mae: 0.2905
# Epoch 58/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.0923 - mae: 0.2258 - val_loss: 0.2153 - val_mae: 0.2830
# Epoch 59/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1047 - mae: 0.2426 - val_loss: 0.2223 - val_mae: 0.2837
# Epoch 60/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1111 - mae: 0.2434 - val_loss: 0.2335 - val_mae: 0.2909
# Epoch 61/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.1081 - mae: 0.2361 - val_loss: 0.2143 - val_mae: 0.3084
# Epoch 62/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.0905 - mae: 0.2206 - val_loss: 0.2075 - val_mae: 0.2701
# Epoch 63/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.0939 - mae: 0.2212 - val_loss: 0.2042 - val_mae: 0.2948
# Epoch 64/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1326 - mae: 0.2523 - val_loss: 0.2578 - val_mae: 0.2990
# Epoch 65/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1065 - mae: 0.2375 - val_loss: 0.2111 - val_mae: 0.2825
# Epoch 66/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.1138 - mae: 0.2464 - val_loss: 0.2255 - val_mae: 0.3214
# Epoch 67/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.0927 - mae: 0.2236 - val_loss: 0.2005 - val_mae: 0.2846
# Epoch 68/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1557 - mae: 0.2598 - val_loss: 0.2267 - val_mae: 0.2969
# Epoch 69/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.0966 - mae: 0.2249 - val_loss: 0.1935 - val_mae: 0.2785
# Epoch 70/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.0825 - mae: 0.2131 - val_loss: 0.1935 - val_mae: 0.2738
# Epoch 71/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.0972 - mae: 0.2242 - val_loss: 0.2092 - val_mae: 0.2708
# Epoch 72/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.1044 - mae: 0.2310 - val_loss: 0.2259 - val_mae: 0.3212
# Epoch 73/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1076 - mae: 0.2376 - val_loss: 0.2072 - val_mae: 0.2951
# Epoch 74/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1006 - mae: 0.2251 - val_loss: 0.2429 - val_mae: 0.2907
# Epoch 75/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.1015 - mae: 0.2264 - val_loss: 0.2034 - val_mae: 0.2965
# Epoch 76/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.0826 - mae: 0.2154 - val_loss: 0.2235 - val_mae: 0.3193
# Epoch 77/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.0894 - mae: 0.2123 - val_loss: 0.2030 - val_mae: 0.2762
# Epoch 78/100
# 36/36 [==============================] - 1s 23ms/step - loss: 0.0839 - mae: 0.2195 - val_loss: 0.2442 - val_mae: 0.2877
# Epoch 79/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.0981 - mae: 0.2209 - val_loss: 0.2099 - val_mae: 0.2811
# Saved model for CO to saved_models\model_CO.h5
#
# Training model for SO2
# Training samples: 354, Testing samples: 89
# Epoch 1/100
# 36/36 [==============================] - 3s 39ms/step - loss: 1.0314 - mae: 0.8370 - val_loss: 0.7638 - val_mae: 0.7781
# Epoch 2/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.9911 - mae: 0.8083 - val_loss: 0.7492 - val_mae: 0.7879
# Epoch 3/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.8877 - mae: 0.7537 - val_loss: 0.8623 - val_mae: 0.8667
# Epoch 4/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.9517 - mae: 0.7919 - val_loss: 0.6833 - val_mae: 0.7621
# Epoch 5/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.8171 - mae: 0.7202 - val_loss: 0.4854 - val_mae: 0.5983
# Epoch 6/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.7546 - mae: 0.6815 - val_loss: 0.4074 - val_mae: 0.4911
# Epoch 7/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.6419 - mae: 0.6223 - val_loss: 0.3720 - val_mae: 0.4379
# Epoch 8/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6096 - mae: 0.5893 - val_loss: 0.4269 - val_mae: 0.5446
# Epoch 9/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.5600 - mae: 0.5737 - val_loss: 0.3680 - val_mae: 0.4477
# Epoch 10/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6564 - mae: 0.6222 - val_loss: 0.4645 - val_mae: 0.5832
# Epoch 11/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.5654 - mae: 0.5782 - val_loss: 0.6393 - val_mae: 0.6992
# Epoch 12/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.5529 - mae: 0.5649 - val_loss: 0.3703 - val_mae: 0.4610
# Epoch 13/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.5084 - mae: 0.5429 - val_loss: 0.4310 - val_mae: 0.5350
# Epoch 14/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.4972 - mae: 0.5317 - val_loss: 0.3521 - val_mae: 0.4466
# Epoch 15/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.4209 - mae: 0.4719 - val_loss: 0.3609 - val_mae: 0.4480
# Epoch 16/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.4487 - mae: 0.4992 - val_loss: 0.3503 - val_mae: 0.4500
# Epoch 17/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.4024 - mae: 0.4687 - val_loss: 0.4394 - val_mae: 0.5062
# Epoch 18/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.4148 - mae: 0.4745 - val_loss: 0.4316 - val_mae: 0.5306
# Epoch 19/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.3726 - mae: 0.4533 - val_loss: 0.3930 - val_mae: 0.4924
# Epoch 20/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.3876 - mae: 0.4659 - val_loss: 0.3716 - val_mae: 0.4545
# Epoch 21/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.3598 - mae: 0.4364 - val_loss: 0.3455 - val_mae: 0.4303
# Epoch 22/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.3417 - mae: 0.4260 - val_loss: 0.3745 - val_mae: 0.4263
# Epoch 23/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.3497 - mae: 0.4261 - val_loss: 0.3570 - val_mae: 0.4262
# Epoch 24/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.3371 - mae: 0.4221 - val_loss: 0.3356 - val_mae: 0.3934
# Epoch 25/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.3554 - mae: 0.4234 - val_loss: 0.3637 - val_mae: 0.4139
# Epoch 26/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.3543 - mae: 0.4425 - val_loss: 0.3627 - val_mae: 0.4029
# Epoch 27/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.3072 - mae: 0.3956 - val_loss: 0.4901 - val_mae: 0.5100
# Epoch 28/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.2925 - mae: 0.3965 - val_loss: 0.4086 - val_mae: 0.4309
# Epoch 29/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.3413 - mae: 0.4040 - val_loss: 0.4654 - val_mae: 0.4856
# Epoch 30/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.3094 - mae: 0.4077 - val_loss: 0.3540 - val_mae: 0.3978
# Epoch 31/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.2742 - mae: 0.3652 - val_loss: 0.4261 - val_mae: 0.4236
# Epoch 32/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2853 - mae: 0.3813 - val_loss: 0.4279 - val_mae: 0.4250
# Epoch 33/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.2990 - mae: 0.3882 - val_loss: 0.4076 - val_mae: 0.4402
# Epoch 34/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.3413 - mae: 0.3990 - val_loss: 0.6344 - val_mae: 0.6102
# Saved model for SO2 to saved_models\model_SO2.h5
#
# Training model for NO2
# Training samples: 354, Testing samples: 89
# Epoch 1/100
# 36/36 [==============================] - 4s 48ms/step - loss: 1.0130 - mae: 0.8318 - val_loss: 1.0817 - val_mae: 0.9122
# Epoch 2/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.9884 - mae: 0.8317 - val_loss: 1.0356 - val_mae: 0.8506
# Epoch 3/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.9840 - mae: 0.8195 - val_loss: 0.9943 - val_mae: 0.8078
# Epoch 4/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.9484 - mae: 0.7852 - val_loss: 1.0452 - val_mae: 0.9092
# Epoch 5/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.8804 - mae: 0.7546 - val_loss: 0.7446 - val_mae: 0.5821
# Epoch 6/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.7949 - mae: 0.6817 - val_loss: 0.5687 - val_mae: 0.5316
# Epoch 7/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0
100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.2329 - mae: 0.3410 - val_loss: 0.2285 - val_mae: 0.3236
# Epoch 41/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.1810 - mae: 0.3029 - val_loss: 0.1762 - val_mae: 0.2559
# Epoch 42/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1833 - mae: 0.2978 - val_loss: 0.1948 - val_mae: 0.2797
# Epoch 43/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1897 - mae: 0.2923 - val_loss: 0.1913 - val_mae: 0.3017
# Epoch 44/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1847 - mae: 0.2926 - val_loss: 0.2239 - val_mae: 0.2920
# Epoch 45/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.1707 - mae: 0.2865 - val_loss: 0.2103 - val_mae: 0.2934
# Epoch 46/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1596 - mae: 0.2712 - val_loss: 0.1915 - val_mae: 0.2859
# Epoch 47/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.1805 - mae: 0.2923 - val_loss: 0.2123 - val_mae: 0.2594
# Epoch 48/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.1870 - mae: 0.2993 - val_loss: 0.2049 - val_mae: 0.2792
# Epoch 49/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1753 - mae: 0.2943 - val_loss: 0.2115 - val_mae: 0.2780
# Epoch 50/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.1713 - mae: 0.2830 - val_loss: 0.2025 - val_mae: 0.2510
# Epoch 51/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.1714 - mae: 0.2847 - val_loss: 0.2123 - val_mae: 0.2717
# Saved model for NO2 to saved_models\model_NO2.h5

# %%
plt.figure(figsize=(12, 6))
for param, history in histories.items():
    plt.plot(history.history['mae'], label=f'{param} Train MAE')
    plt.plot(history.history['val_mae'], label=f'{param} Val MAE', linestyle='--')
plt.title('Training and Validation MAE Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
def test_model(models, X_test=None, y_test_dict=None, scalers=None, new_image_path=None):
    results = {}
    
    if X_test is not None and y_test_dict is not None:
        print(f"\nEvaluating on test data (sequences: {X_test.shape[0]})")
        for param, model in models.items():
            test_loss, test_mae = model.evaluate(X_test, y_test_dict[param][:, -1], verbose=0)
            y_pred_scaled = model.predict(X_test, verbose=0).flatten()
            y_pred = scalers[param].inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()
            y_true = scalers[param].inverse_transform(y_test_dict[param][:, -1].reshape(-1, 1)).flatten()
            r2 = r2_score(y_true, y_pred)
            results[param] = {'MSE': test_loss, 'MAE': test_mae, 'R²': r2}
            print(f"{param} - Test MSE (scaled): {test_loss:.4f}, Test MAE (scaled): {test_mae:.4f}, R²: {r2:.4f}")
            print(f"Sample predictions (unscaled): {y_pred[:5]}, Actual: {y_true[:5]}")
    
    elif new_image_path is not None:
        print("\nPredicting for a new sequence:")
        img_resized = load_and_preprocess_image(new_image_path)
        sky_img_seq = np.expand_dims(img_resized, axis=0)
        sky_img_seq = np.repeat(sky_img_seq[np.newaxis, :], TIMESTEPS, axis=1)
        
        for param, model in models.items():
            pred_scaled = model.predict(sky_img_seq, verbose=0)[0]
            pred = scalers[param].inverse_transform([[pred_scaled]])[0][0]
            results[param] = pred
            print(f"Predicted {param}: {pred:.4f}")
    
    return results

X_train, X_test, y_train_dict, y_test_dict = {}, {}, {}, {}
for param, y_values in y_dict.items():
    X_train[param], X_test[param], y_train_dict[param], y_test_dict[param] = train_test_split(
        X, y_values, test_size=0.2, random_state=42
    )

test_results = test_model(models, X_test['AQI'], y_test_dict, scalers)
new_image = "F:/Pheonix/Thesis/Project/Code/AQI Index/.venv/Dev/Data/test_image.jpg"
pred_results = test_model(models, new_image_path=new_image, scalers=scalers)
# Out:
# Evaluating on test data (sequences: 89)
# AQI - Test MSE (scaled): 0.2113, Test MAE (scaled): 0.3776, R²: 0.7457
# Sample predictions (unscaled): [318.26584   70.050705 121.136505  52.26617  102.123764], Actual: [363. 121.  91.  97. 101.]
# PM2.5 - Test MSE (scaled): 0.1095, Test MAE (scaled): 0.2363, R²: 0.8836
# Sample predictions (unscaled): [251.00464   35.63938   54.108536  21.978813  47.098732], Actual: [257.    70.    30.27  43.    33.18]
# PM10 - Test MSE (scaled): 0.1779, Test MAE (scaled): 0.3161, R²: 0.8131
# Sample predictions (unscaled): [134.44939  76.40003  87.56578  44.51153  84.69585], Actual: [139.   113.    44.12  78.    48.66]
# O3 - Test MSE (scaled): 0.3201, Test MAE (scaled): 0.3792, R²: 0.5174
# Sample predictions (unscaled): [52.679474 22.008638 42.886333 25.395916 66.77156 ], Actual: [41.   21.   42.15 26.   68.31]
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000225AF8EECA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# CO - Test MSE (scaled): 0.1935, Test MAE (scaled): 0.2785, R²: 0.8240
# Sample predictions (unscaled): [ 41.776714  357.5023     19.744213  246.50069     2.5895343], Actual: [6.50e+01 4.09e+02 3.00e-01 2.58e+02 2.50e-01]
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000225AFC9FC10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# SO2 - Test MSE (scaled): 0.3356, Test MAE (scaled): 0.3934, R²: 0.5429
# Sample predictions (unscaled): [20.34037   18.511127   4.0008383  8.135697   3.4953403], Actual: [35.   20.    4.1  10.    3.25]
# NO2 - Test MSE (scaled): 0.1762, Test MAE (scaled): 0.2559, R²: 0.8277
# Sample predictions (unscaled): [84.93924   18.180378   7.0689616 19.120266   4.587726 ], Actual: [83.   18.    2.57 17.    0.67]
#
# Predicting for a new sequence:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 38
#      36 test_results = test_model(models, X_test['AQI'], y_test_dict, scalers)
#      37 new_image = "F:/Pheonix/Thesis/Project/Code/AQI Index/.venv/Dev/Data/test_image.jpg"
# ---> 38 pred_results = test_model(models, new_image_path=new_image, scalers=scalers)
#
# Cell In[7], line 18, in test_model(models, X_test, y_test_dict, scalers, new_image_path)
#      16 elif new_image_path is not None:
#      17     print("\nPredicting for a new sequence:")
# ---> 18     img_resized = load_and_preprocess_image(new_image_path)
#      19     sky_img_seq = np.expand_dims(img_resized, axis=0)
#      20     sky_img_seq = np.repeat(sky_img_seq[np.newaxis, :], TIMESTEPS, axis=1)
#
# Cell In[2], line 5, in load_and_preprocess_image(image_path)
#       3 img = cv2.imread(image_path)
#       4 if img is None:
# ----> 5     raise ValueError(f"Could not load image at {image_path}")
#       6 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       7 img_resized = cv2.resize(img, (IMAGE_WIDTH, IMAGE_HEIGHT))
#
# ValueError: Could not load image at F:/Pheonix/Thesis/Project/Code/AQI Index/.venv/Dev/Data/test_image.jpg

# %%
img = load_and_preprocess_image(new_image)

plt.figure(figsize=(10, 5))
plt.imshow(img)
plt.title("Original Image")
plt.axis('off')
plt.suptitle("Sample Image with Predictions:\n" + 
             "\n".join(f"{param}: {value:.2f}" for param, value in pred_results.items()))
plt.show()
